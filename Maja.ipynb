# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("spotify_songs.csv")

# %%
df.head(1)
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
#
#   track_artist  track_popularity          track_album_id  \
# 0   Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
#
#                                     track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...               2019-06-14
#
#   playlist_name             playlist_id playlist_genre  ... key  loudness  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   6    -2.634
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0583         0.102               0.0    0.0653    0.518
#
#      tempo  duration_ms
# 0  122.036       194754
#
# [1 rows x 23 columns]

# %%
# Returns df only with artists with more than 100 tracks on the chart

artist_counts = df.track_artist.value_counts()
top_100_artists = artist_counts[artist_counts >= 100].index.tolist()
top_artists = df[df['track_artist'].isin(top_100_artists)]

# %%
# Assigning top artists a popularity score based on number of tracks on chart
top_artists_popularity_score = top_artists['track_artist'].value_counts().to_dict()
top_artists['popularity'] = top_artists['track_artist'].map(top_artists_popularity_score)
# Out:
# /var/folders/_v/swcgdh2j22n2qvz2080yh82c0000gn/T/ipykernel_7821/497223521.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_artists['popularity'] = top_artists['track_artist'].map(top_artists_popularity_score)

# %%
# Normalizing popularity score
X_min = 20
X_max = 161

top_artists['normalized_score'] = (top_artists['popularity'] - X_min) / (X_max - X_min)
top_artists
# Out:
# /var/folders/_v/swcgdh2j22n2qvz2080yh82c0000gn/T/ipykernel_7821/3413800084.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_artists['normalized_score'] = (top_artists['popularity'] - X_min) / (X_max - X_min)
#                      track_id  \
# 3      75FpbthrwQmzHlBJLuGdC7
# 14     55nMnifaQWKe3f9cbwOXwx
# 17     3TjLsDgL0bTbSQIF6M5Ki8
# 22     1mC2UjWt25Oixtqu7C6suL
# 24     4sqABRRGU7CzcHXCyxUzFw
# ...                       ...
# 32551  6lBQ0SMCrJ7zy1LSCuXqwV
# 32553  0sfbunyd3a7IFoWwEt8dsk
# 32562  27YP211Rr8RezhiFVDLFI8
# 32734  5qIzTkMpgEFfvkDdr9zJzg
# 32773  1jvT3CCQpyysWB1JcqZwSi
#
#                                               track_name      track_artist  \
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 14     Summer Days (feat. Macklemore & Patrick Stump ...     Martin Garrix
# 17     Say My Name (feat. Bebe Rexha & J Balvin) - Lu...      David Guetta
# 22     Don't Leave Me Alone (feat. Anne-Marie) - EDX'...      David Guetta
# 24     Do You Mean (feat. Ty Dolla $ign & bülow) - My...  The Chainsmokers
# ...                                                  ...               ...
# 32551                                  Lions in the Wild     Martin Garrix
# 32553  Don't Leave Me Alone (feat. Anne-Marie) - Oliv...      David Guetta
# 32562          Waiting For Tomorrow (feat. Mike Shinoda)     Martin Garrix
# 32734  Stay (Don't Go Away) [feat. Raye] - Nicky Rome...      David Guetta
# 32773               Just One Last Time (feat. Taped Rai)      David Guetta
#
#        track_popularity          track_album_id  \
# 3                    60  1nqYsOef1yKKuGOVchbsk6
# 14                   63  2vx3BtBMn8Ed3ygEg1OT2t
# 17                   65  19z3vpbBT09lZ54neDfuFL
# 22                   62  1WhPuMFm5VaTJqe9rl3C5Q
# 24                   58  5vf16sRhXB2f3sS5kteU2T
# ...                 ...                     ...
# 32551                57  2x8X4Dq12rXdQsmk41F3VV
# 32553                49  4o8Y3L9WQvk3L3u9M0gngq
# 32562                59  5dv1oLETxdsYOkS2Sic00z
# 32734                54  7biIbzlDBUbV7p3SOwlF1q
# 32773                41  5aprcHwM1KJhaY9Kbxkfkn
#
#                                         track_album_name  \
# 3                            Call You Mine - The Remixes
# 14     Summer Days (feat. Macklemore & Patrick Stump ...
# 17     Say My Name (feat. Bebe Rexha & J Balvin) [Luc...
# 22     Don't Leave Me Alone (feat. Anne-Marie) [EDX's...
# 24     Do You Mean - The Remixes (feat. Ty Dolla $ign...
# ...                                                  ...
# 32551                                  Lions in the Wild
# 32553  Don't Leave Me Alone (feat. Anne-Marie) [Olive...
# 32562                                           BYLAW EP
# 32734  Stay (Don't Go Away) [feat. Raye] [Nicky Romer...
# 32773                           Nothing but the Beat 2.0
#
#       track_album_release_date  \
# 3                   2019-07-19
# 14                  2019-07-12
# 17                  2018-12-28
# 22                  2019-05-08
# 24                  2019-05-24
# ...                        ...
# 32551               2016-05-27
# 32553               2018-08-31
# 32562               2018-10-19
# 32734               2019-06-14
# 32773               2011-08-26
#
#                                            playlist_name  \
# 3                                              Pop Remix
# 14                                             Pop Remix
# 17                                             Pop Remix
# 22                                             Pop Remix
# 24                                             Pop Remix
# ...                                                  ...
# 32551  Festival Music 2019 - Warm Up Music (EDM, Big ...
# 32553  Festival Music 2019 - Warm Up Music (EDM, Big ...
# 32562  Festival Music 2019 - Warm Up Music (EDM, Big ...
# 32734                         Trending EDM by Nik Cooper
# 32773                                    ♥ EDM LOVE 2020
#
#                   playlist_id playlist_genre  ... mode  speechiness  \
# 3      37i9dQZF1DXcZDD7cfEKhW            pop  ...    1       0.1020
# 14     37i9dQZF1DXcZDD7cfEKhW            pop  ...    0       0.0594
# 17     37i9dQZF1DXcZDD7cfEKhW            pop  ...    0       0.1650
# 22     37i9dQZF1DXcZDD7cfEKhW            pop  ...    0       0.1280
# 24     37i9dQZF1DXcZDD7cfEKhW            pop  ...    1       0.0352
# ...                       ...            ...  ...  ...          ...
# 32551  73uj4YmsC7SJ6SbUMTvf07            edm  ...    0       0.0442
# 32553  73uj4YmsC7SJ6SbUMTvf07            edm  ...    0       0.0612
# 32562  73uj4YmsC7SJ6SbUMTvf07            edm  ...    0       0.1410
# 32734  4N1ipiKR3xla8UXtE12XBm            edm  ...    1       0.0477
# 32773  6jI1gFr6ANFtT8MmTvA2Ux            edm  ...    1       0.0579
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 3           0.02870          0.000009    0.2040    0.277  121.956
# 14          0.00733          0.001830    0.0729    0.238  126.070
# 17          0.03950          0.000000    0.1740    0.516  120.002
# 22          0.04690          0.000003    0.1190    0.336  123.938
# 24          0.01630          0.000019    0.3950    0.422  110.018
# ...             ...               ...       ...      ...      ...
# 32551       0.00434          0.000000    0.8160    0.280  127.854
# 32553       0.00790          0.000056    0.3590    0.155  125.965
# 32562       0.00731          0.000000    0.5620    0.336  128.015
# 32734       0.00569          0.000637    0.1610    0.233  124.986
# 32773       0.02060          0.000000    0.1240    0.208  128.022
#
#        duration_ms  popularity  normalized_score
# 3           169093         123          0.730496
# 14          255238         161          1.000000
# 17          189375         110          0.638298
# 22          210968         110          0.638298
# 24          205093         123          0.730496
# ...            ...         ...               ...
# 32551       211890         161          1.000000
# 32553       204224         110          0.638298
# 32562       247505         161          1.000000
# 32734       177889         110          0.638298
# 32773       227107         110          0.638298
#
# [732 rows x 25 columns]

# %%
# Plotting top artists energy and danceability 

import matplotlib.pyplot as plt

top_artists.plot(kind='scatter', x='danceability', y='energy', alpha=0.4, s=top_artists['popularity']/100, label='popularity', figsize=(15,10), c='normalized_score', cmap = plt.get_cmap('jet'), colorbar=True)
plt.legend()

# %%
df_float = pd.DataFrame(df, columns=['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness'])
df_object_playlist = pd.DataFrame(df, columns=['playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre'])
df_object_track = pd.DataFrame(df, columns=['track_id', 'track_name', 'track_artist', 'track_album_id', 'track_album_name', 'track_album_release_date'])

# %%
df_object_track.track_album_release_date.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        2019-06-14
# 1        2019-12-13
# 2        2019-07-05
# 3        2019-07-19
# 4        2019-03-05
#             ...
# 32828    2014-04-28
# 32829    2013-03-08
# 32830    2014-04-21
# 32831    2014-01-01
# 32832    2014-03-03
# Name: track_album_release_date, Length: 32833, dtype: object>

# %%
corr_matrix = df_float.corr()
print(corr_matrix)
# Out:
#                   danceability    energy  loudness  speechiness  acousticness  \
# danceability          1.000000 -0.086073  0.025335     0.181721     -0.024519
# energy               -0.086073  1.000000  0.676625    -0.032150     -0.539745
# loudness              0.025335  0.676625  1.000000     0.010339     -0.361638
# speechiness           0.181721 -0.032150  0.010339     1.000000      0.026092
# acousticness         -0.024519 -0.539745 -0.361638     0.026092      1.000000
# instrumentalness     -0.008655  0.033247 -0.147824    -0.103424     -0.006850
# liveness             -0.123859  0.161223  0.077613     0.055426     -0.077243
#
#                   instrumentalness  liveness
# danceability             -0.008655 -0.123859
# energy                    0.033247  0.161223
# loudness                 -0.147824  0.077613
# speechiness              -0.103424  0.055426
# acousticness             -0.006850 -0.077243
# instrumentalness          1.000000 -0.005507
# liveness                 -0.005507  1.000000

# %%
corr_matrix['danceability'].sort_values(ascending=True)
# Out:
# liveness           -0.123859
# energy             -0.086073
# acousticness       -0.024519
# instrumentalness   -0.008655
# loudness            0.025335
# speechiness         0.181721
# danceability        1.000000
# Name: danceability, dtype: float64

# %%
# Correlation heatmap
import seaborn as sns

plt.figure(figsize=(14,14))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.show()

# %%
sns.pairplot(df_float, corner=True)
plt.show()

# %%
df_float.plot(kind='scatter', x='energy', y='loudness', alpha=0.01)
plt.show()

# %%
df_float.plot(kind='scatter', x='acousticness', y='energy', alpha=0.01)
plt.show()

# %%
df_float.plot(kind='scatter', x='danceability', y='speechiness', alpha=0.01)
plt.show()
